# %%
import tensorflow as tf

# %%
import numpy as np

# %%
from IPython.display import Image

# %%
file = 'images//cute.jpg'

# %%
Image(file, width=224, height=224)

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()
# Out:
# ...
# 17225924/17225924 [==============================] - 28s 2us/step
